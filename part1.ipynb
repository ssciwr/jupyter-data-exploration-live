# %% [markdown]
# # SSC Jupyter Course

# %%
print("hello")
# Out:
# hello

# %%
# comment - ignored by python

# %%
2 + 2
# Out:
# 4

# %% [markdown]
# ## Markdown

# %% [markdown]
# ## level 2
#
# a list:
#
# - item 1
# - item 2
# - [a link](www.google.com)
# - latex $\int_0^\infty dx$
#
# $$
# \int_0^\infty dx
# $$
#
# ![an image](https://ssc.iwr.uni-heidelberg.de/sites/default/files/ssc-iwr-hd-logo.svg)

# %%
3*3
# Out:
# 9

# %% [markdown]
# ### level 3

# %% [markdown]
# ## Python variables

# %%
a = 10

# %%
print(a)
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
a = "hello"

# %%
print(a)
# Out:
# hello

# %%
type(a)
# Out:
# str

# %%
a = 10

# %%
a = a + 1

# %%
print(a)
# Out:
# 10

# %% [markdown]
# ## Python lists

# %%
my_list = [1, 2, 3.1, "ok"]

# %%
# first item: index zero
my_list[0]
# Out:
# 1

# %%
# last item: negative indices
my_list[-1]
# Out:
# 'ok'

# %%
my_list[3]
# Out:
# 'ok'

# %%
# slices
my_list[2:4]
# Out:
# [3.1, 'ok']

# %%
my_list[:4]
# Out:
# [1, 2, 3.1, 'ok']

# %%
my_list[-2:]
# Out:
# [3.1, 'ok']

# %%
my_list[:]
# Out:
# [1, 2, 3.1, 'ok']

# %%
list2 = ["a", 'b']

# %%
list3 = my_list + list2

# %%
print(list3)
# Out:
# [1, 2, 3.1, 'ok', 'a', 'b']

# %%
my_list + list2
# Out:
# [1, 2, 3.1, 'ok', 'a', 'b']

# %%
my_list
# Out:
# [1, 2, 3.1, 'ok']

# %%
for x in list3:
    print(x)
# Out:
# 1
# 2
# 3.1
# ok
# a
# b

# %%
total = 0

for x in list3[0:3]:
    total = total + x

print(total)
# Out:
# 6.1

# %% [markdown]
# ## Python dictionaries

# %%
my_dict = {"name": "bob", "age": 12}

# %%
print(my_dict)
# Out:
# {'name': 'bob', 'age': 12}

# %%
type(my_dict)
# Out:
# dict

# %%
len(my_dict)
# Out:
# 2

# %%
my_dict["nickname"] = "b"

# %%
print(my_dict)
# Out:
# {'name': 'bob', 'age': 12, 'nickname': 'b'}

# %%
my_dict["age"] = 14

# %%
print(my_dict)
# Out:
# {'name': 'bob', 'age': 14, 'nickname': 'b'}

# %%
for key in my_dict:
    print(key)
# Out:
# name
# age
# nickname

# %%
for key, value in my_dict.items():
    print(key, value)
# Out:
# name bob
# age 14
# nickname b

# %% [markdown]
# ## Python functions

# %%
def sum_numbers(a, b):
    return a + b

# %%
sum_numbers(1, 2)
# Out:
# 3

# %% [markdown]
# ## Python libraries

# %%
import numpy as np

# %%
a = np.array([1, 2, 3])

# %%
a
# Out:
# array([1, 2, 3])

# %%
np.sum(a)
# Out:
# 6
