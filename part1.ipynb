# %% [markdown]
# # SSC Jupyter Course

# %%
print("hello")
# Out:
# hello

# %%
# comment - ignored by python

# %%
2 + 2
# Out:
# 4

# %% [markdown]
# ## Markdown

# %% [markdown]
# ## level 2
#
# a list:
#
# - item 1
# - item 2
# - [a link](www.google.com)
# - latex $\int_0^\infty dx$
#
# $$
# \int_0^\infty dx
# $$

# %% [markdown]
# ### level 3
