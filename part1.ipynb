# %% [markdown]
# # SSC Jupyter Course

# %%
print("hello")
# Out:
# hello

# %%
# comment - ignored by python

# %%
2 + 2
# Out:
# 4

# %% [markdown]
# ## Markdown

# %% [markdown]
# ## level 2
#
# a list:
#
# - item 1
# - item 2
# - [a link](www.google.com)
# - latex $\int_0^\infty dx$
#
# $$
# \int_0^\infty dx
# $$
#
# ![an image](https://ssc.iwr.uni-heidelberg.de/sites/default/files/ssc-iwr-hd-logo.svg)

# %%
3*3
# Out:
# 9

# %% [markdown]
# ### level 3

# %% [markdown]
# ## Python variables

# %%
a = 10

# %%
print(a)
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
a = "hello"

# %%
print(a)
# Out:
# hello

# %%
type(a)
# Out:
# str

# %%
a = 10

# %%
a = a + 1

# %%
print(a)
# Out:
# 10
