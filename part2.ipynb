# %% [markdown]
# ## SSC Jupyter course part 2

# %%
import pandas as pd

# %%
df = pd.read_csv("https://ssciwr.github.io/jupyter-data-exploration/data.csv")

# %%
print(df)
# Out:
#        Name  Age     Sex  Height Eye colour Wears glasses
# 0       Bob   12    Male   130.0       blue           yes
# 1     Simon   13    Male   120.0       blue            no
# 2     Clare   15  Female   142.5      green            no
# 3      Jose   11    Male   117.0      brown            no
# 4    Hannah    9  Female   111.0       blue           yes
# 5      Ryan   11    Male   124.0      brown            no
# 6     Craig   12    Male   124.0      brown            no
# 7      Suzy   14  Female   137.0       grey           yes
# 8     Chris   10    Male   112.5      brown            no
# 9     Josie    8  Female   107.0      brown            no
# 10   Claire   16  Female   158.0       blue            no
# 11     John    5    Male    97.0       grey            no
# 12    Agnes    6  Female    98.0       blue           yes
# 13   Robert    8    Male   109.0      brown            no
# 14    Julia    3  Female    63.0       blue            no
# ...

# %%
df.head(2)
# Out:
#     Name  Age   Sex  Height Eye colour Wears glasses
# 0    Bob   12  Male   130.0       blue           yes
# 1  Simon   13  Male   120.0       blue            no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           20 non-null     object
#  1   Age            20 non-null     int64
#  2   Sex            20 non-null     object
#  3   Height         20 non-null     float64
#  4   Eye colour     20 non-null     object
#  5   Wears glasses  20 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.1+ KB

# %% [markdown]
# ## Selecting rows/columns: `[]`

# %%
# df is like a dict
df.columns
# Out:
# Index(['Name', 'Age', 'Sex', 'Height', 'Eye colour', 'Wears glasses'], dtype='object')

# %%
heights = df["Height"]

# %%
type(heights)
# Out:
# pandas.core.series.Series

# %%
len(heights)
# Out:
# 20

# %%
print(heights)
# Out:
# 0     130.0
# 1     120.0
# 2     142.5
# 3     117.0
# 4     111.0
# 5     124.0
# 6     124.0
# 7     137.0
# 8     112.5
# 9     107.0
# 10    158.0
# 11     97.0
# 12     98.0
# 13    109.0
# 14     63.0
# 15    101.0
# 16    107.0
# 17    121.0
# 18    106.0
# 19     59.0
# Name: Height, dtype: float64

# %%
# series is like a list
heights[0]
# Out:
# 130.0

# %%
heights[4:8]
# Out:
# 4    111.0
# 5    124.0
# 6    124.0
# 7    137.0
# Name: Height, dtype: float64

# %%
heights[[1,2,5,8]]
# Out:
# 1    120.0
# 2    142.5
# 5    124.0
# 8    112.5
# Name: Height, dtype: float64

# %%
for height in heights:
    print(height)
# Out:
# 130.0
# 120.0
# 142.5
# 117.0
# 111.0
# 124.0
# 124.0
# 137.0
# 112.5
# 107.0
# 158.0
# 97.0
# 98.0
# 109.0
# 63.0
# 101.0
# 107.0
# 121.0
# 106.0
# 59.0

# %%
# alternative syntax:
df.Height
# Out:
# 0     130.0
# 1     120.0
# 2     142.5
# 3     117.0
# 4     111.0
# 5     124.0
# 6     124.0
# 7     137.0
# 8     112.5
# 9     107.0
# 10    158.0
# 11     97.0
# 12     98.0
# 13    109.0
# 14     63.0
# 15    101.0
# 16    107.0
# 17    121.0
# 18    106.0
# 19     59.0
# Name: Height, dtype: float64

# %%
# caveat: this doesn't work:
# df.Eye colour

# %% [markdown]
# ## Selecting rows/columns: `iloc`

# %%
# first row
df.iloc[0, :]
# Out:
# Name               Bob
# Age                 12
# Sex               Male
# Height           130.0
# Eye colour        blue
# Wears glasses      yes
# Name: 0, dtype: object

# %%
# equivalent
df.iloc[0]
# Out:
# Name               Bob
# Age                 12
# Sex               Male
# Height           130.0
# Eye colour        blue
# Wears glasses      yes
# Name: 0, dtype: object

# %%
# first column
df.iloc[:, 0]
# Out:
# 0         Bob
# 1       Simon
# 2       Clare
# 3        Jose
# 4      Hannah
# 5        Ryan
# 6       Craig
# 7        Suzy
# 8       Chris
# 9       Josie
# 10     Claire
# 11       John
# 12      Agnes
# 13     Robert
# 14      Julia
# 15     Fabian
# 16     Joseph
# 17    Roberta
# 18      Chris
# 19      Lucas
# Name: Name, dtype: object

# %%
df.iloc[0,0]
# Out:
# 'Bob'

# %%
df.iloc[2:4, 4:5]
# Out:
#   Eye colour
# 2      green
# 3      brown

# %%
df.iloc[[1,3,6], [3,4]]
# Out:
#    Height Eye colour
# 1   120.0       blue
# 3   117.0      brown
# 6   124.0      brown

# %% [markdown]
# ## Selecting rows/columns: `iloc`

# %%
# row with index label "0"
df.loc[0]
# Out:
# Name               Bob
# Age                 12
# Sex               Male
# Height           130.0
# Eye colour        blue
# Wears glasses      yes
# Name: 0, dtype: object

# %%
# equivalent
df.loc[0, :]
# Out:
# Name               Bob
# Age                 12
# Sex               Male
# Height           130.0
# Eye colour        blue
# Wears glasses      yes
# Name: 0, dtype: object

# %%
# Age column
df.loc[:, "Age"]
# Out:
# 0     12
# 1     13
# 2     15
# 3     11
# 4      9
# 5     11
# 6     12
# 7     14
# 8     10
# 9      8
# 10    16
# 11     5
# 12     6
# 13     8
# 14     3
# 15     5
# 16     8
# 17    11
# 18     8
# 19     2
# Name: Age, dtype: int64

# %%
# Slices are *inclusive*
df.loc[:, "Age":"Eye colour"]
# Out:
#     Age     Sex  Height Eye colour
# 0    12    Male   130.0       blue
# 1    13    Male   120.0       blue
# 2    15  Female   142.5      green
# 3    11    Male   117.0      brown
# 4     9  Female   111.0       blue
# 5    11    Male   124.0      brown
# 6    12    Male   124.0      brown
# 7    14  Female   137.0       grey
# 8    10    Male   112.5      brown
# 9     8  Female   107.0      brown
# 10   16  Female   158.0       blue
# 11    5    Male    97.0       grey
# 12    6  Female    98.0       blue
# 13    8    Male   109.0      brown
# 14    3  Female    63.0       blue
# 15    5    Male   101.0       blue
# 16    8    Male   107.0      brown
# 17   11  Female   121.0       grey
# 18    8    Male   106.0      brown
# 19    2    Male    59.0       blue

# %%
# important difference!
df.iloc[0:2, :]
# Out:
#     Name  Age   Sex  Height Eye colour Wears glasses
# 0    Bob   12  Male   130.0       blue           yes
# 1  Simon   13  Male   120.0       blue            no

# %%
df.loc[0:2, :]
# Out:
#     Name  Age     Sex  Height Eye colour Wears glasses
# 0    Bob   12    Male   130.0       blue           yes
# 1  Simon   13    Male   120.0       blue            no
# 2  Clare   15  Female   142.5      green            no

# %%
df.loc[[2,3,4], ["Eye colour", "Age"]]
# Out:
#   Eye colour  Age
# 2      green   15
# 3      brown   11
# 4       blue    9

# %% [markdown]
# ## Conditionals

# %%
# return True or False
5 < 6
# Out:
# True

# %%
5 <= 5
# Out:
# True

# %%
5 < 5
# Out:
# False

# %%
3 == 3
# Out:
# True

# %%
3 != 3
# Out:
# False

# %%
df["Age"] > 10
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5      True
# 6      True
# 7      True
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18    False
# 19    False
# Name: Age, dtype: bool

# %%
df.loc[df["Age"] > 10]
# Out:
#        Name  Age     Sex  Height Eye colour Wears glasses
# 0       Bob   12    Male   130.0       blue           yes
# 1     Simon   13    Male   120.0       blue            no
# 2     Clare   15  Female   142.5      green            no
# 3      Jose   11    Male   117.0      brown            no
# 5      Ryan   11    Male   124.0      brown            no
# 6     Craig   12    Male   124.0      brown            no
# 7      Suzy   14  Female   137.0       grey           yes
# 10   Claire   16  Female   158.0       blue            no
# 17  Roberta   11  Female   121.0       grey            no

# %%
(df["Age"] > 10) & (df["Eye colour"] == "blue")
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
older_than_ten = df["Age"] > 10

# %%
blue_eyes = df["Eye colour"] == "blue"

# %%
older_than_ten & blue_eyes
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
df.loc[older_than_ten]
# Out:
#        Name  Age     Sex  Height Eye colour Wears glasses
# 0       Bob   12    Male   130.0       blue           yes
# 1     Simon   13    Male   120.0       blue            no
# 2     Clare   15  Female   142.5      green            no
# 3      Jose   11    Male   117.0      brown            no
# 5      Ryan   11    Male   124.0      brown            no
# 6     Craig   12    Male   124.0      brown            no
# 7      Suzy   14  Female   137.0       grey           yes
# 10   Claire   16  Female   158.0       blue            no
# 17  Roberta   11  Female   121.0       grey            no

# %%
df.loc[blue_eyes]
# Out:
#       Name  Age     Sex  Height Eye colour Wears glasses
# 0      Bob   12    Male   130.0       blue           yes
# 1    Simon   13    Male   120.0       blue            no
# 4   Hannah    9  Female   111.0       blue           yes
# 10  Claire   16  Female   158.0       blue            no
# 12   Agnes    6  Female    98.0       blue           yes
# 14   Julia    3  Female    63.0       blue            no
# 15  Fabian    5    Male   101.0       blue            no
# 19   Lucas    2    Male    59.0       blue            no

# %%
df.loc[older_than_ten & blue_eyes]
# Out:
#       Name  Age     Sex  Height Eye colour Wears glasses
# 0      Bob   12    Male   130.0       blue           yes
# 1    Simon   13    Male   120.0       blue            no
# 10  Claire   16  Female   158.0       blue            no

# %%
df.loc[older_than_ten | blue_eyes]
# Out:
#        Name  Age     Sex  Height Eye colour Wears glasses
# 0       Bob   12    Male   130.0       blue           yes
# 1     Simon   13    Male   120.0       blue            no
# 2     Clare   15  Female   142.5      green            no
# 3      Jose   11    Male   117.0      brown            no
# 4    Hannah    9  Female   111.0       blue           yes
# 5      Ryan   11    Male   124.0      brown            no
# 6     Craig   12    Male   124.0      brown            no
# 7      Suzy   14  Female   137.0       grey           yes
# 10   Claire   16  Female   158.0       blue            no
# 12    Agnes    6  Female    98.0       blue           yes
# 14    Julia    3  Female    63.0       blue            no
# 15   Fabian    5    Male   101.0       blue            no
# 17  Roberta   11  Female   121.0       grey            no
# 19    Lucas    2    Male    59.0       blue            no

# %% [markdown]
# ## Summarizing data

# %%
df.describe()
# Out:
#              Age      Height
# count  20.000000   20.000000
# mean    9.350000  112.200000
# std     3.869925   23.283945
# min     2.000000   59.000000
# 25%     7.500000  104.750000
# 50%     9.500000  111.750000
# 75%    12.000000  124.000000
# max    16.000000  158.000000

# %%
df["Name"].describe()
# Out:
# count        20
# unique       19
# top       Chris
# freq          2
# Name: Name, dtype: object

# %%
df["Name"].count()
# Out:
# 20

# %%
df["Name"].unique()
# Out:
# array(['Bob', 'Simon', 'Clare', 'Jose', 'Hannah', 'Ryan', 'Craig', 'Suzy',
#        'Chris', 'Josie', 'Claire', 'John', 'Agnes', 'Robert', 'Julia',
#        'Fabian', 'Joseph', 'Roberta', 'Lucas'], dtype=object)

# %%
df["Name"].value_counts()
# Out:
# Chris      2
# Bob        1
# Claire     1
# Roberta    1
# Joseph     1
# Fabian     1
# Julia      1
# Robert     1
# Agnes      1
# John       1
# Josie      1
# Simon      1
# Suzy       1
# Craig      1
# Ryan       1
# Hannah     1
# Jose       1
# Clare      1
# Lucas      1
# Name: Name, dtype: int64

# %%
df["Age"].plot()
# Out:
# <AxesSubplot:>

# %%
df["Age"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Plotting

# %%
# import matplotlib
import matplotlib.pyplot as plt

# %%
# scatter graph of two columns
df.plot.scatter(x="Age", y="Height")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Height'>

# %%
fig, axs = plt.subplots(figsize=(20,12))
df.plot.scatter(x="Age", y="Height", ax=axs, label="Data")
plt.title("Height vs Age")
plt.show()

# %%
fig, axs = plt.subplots(figsize=(12,12))
for sex, colour in [("Male", "black"), ("Female", "blue")]:
    df.loc[df.Sex == sex].plot.scatter(x="Age", y="Height", ax=axs, label=sex, color=colour)
axs.set_title("Height vs Age")
# plt.title("Height vs Age")
plt.show()

# %%
df["Eye colour"].value_counts()
# Out:
# blue     8
# brown    8
# grey     3
# green    1
# Name: Eye colour, dtype: int64

# %%
fig, axs = plt.subplots(ncols=3)
df["Eye colour"].value_counts().plot.pie(ax=axs[0])
df["Wears glasses"].value_counts().plot.pie(ax=axs[1])
df["Sex"].value_counts().plot.pie(ax=axs[2])
# Out:
# <AxesSubplot:ylabel='Sex'>

# %% [markdown]
# ## groupby

# %%
df.groupby(["Sex"])

# %%
for group_name, data in df.groupby(["Sex"]):
    print(group_name, data)
# Out:
# Female        Name  Age     Sex  Height Eye colour Wears glasses
# 2     Clare   15  Female   142.5      green            no
# 4    Hannah    9  Female   111.0       blue           yes
# 7      Suzy   14  Female   137.0       grey           yes
# 9     Josie    8  Female   107.0      brown            no
# 10   Claire   16  Female   158.0       blue            no
# 12    Agnes    6  Female    98.0       blue           yes
# 14    Julia    3  Female    63.0       blue            no
# 17  Roberta   11  Female   121.0       grey            no
# Male       Name  Age   Sex  Height Eye colour Wears glasses
# 0      Bob   12  Male   130.0       blue           yes
# 1    Simon   13  Male   120.0       blue            no
# 3     Jose   11  Male   117.0      brown            no
# 5     Ryan   11  Male   124.0      brown            no
# 6    Craig   12  Male   124.0      brown            no
# 8    Chris   10  Male   112.5      brown            no
# ...

# %%
df.groupby(["Sex"])["Age"].count()
# Out:
# Sex
# Female     8
# Male      12
# Name: Age, dtype: int64

# %%
df.groupby(["Sex"])["Age"].count().plot.pie()
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
# multigroup
multigroup = df.groupby(["Eye colour", "Sex"])["Age"].count()

# %%
# one plotting option
multigroup.plot.pie()
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
# alternatively: unstack multiindex -> dataframe
multigroup.unstack()
# Out:
# Sex         Female  Male
# Eye colour
# blue           4.0   4.0
# brown          1.0   7.0
# green          1.0   NaN
# grey           2.0   1.0

# %%
multigroup.unstack().plot.pie(subplots=True)
# Out:
# array([<AxesSubplot:ylabel='Female'>, <AxesSubplot:ylabel='Male'>],
#       dtype=object)

# %%
# custom apply
df.groupby(["Sex"]).Age.apply(lambda series : series.loc[series > 10].count())
# Out:
# Sex
# Female    4
# Male      5
# Name: Age, dtype: int64
