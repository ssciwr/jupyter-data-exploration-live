# %% [markdown]
# # SSC pandas part 3

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = "https://data.london.gov.uk/download/animal-rescue-incidents-attended-by-lfb/f43b485e-fb35-419c-aa7a-fa75676e5835/Animal%20Rescue%20incidents%20attended%20by%20LFB%20from%20Jan%202009.csv"

# %%
df = pd.read_csv(url, encoding="unicode_escape")

# %%
df.columns
# Out:
# Index(['IncidentNumber', 'DateTimeOfCall', 'CalYear', 'FinYear',
#        'TypeOfIncident', 'PumpCount', 'PumpHoursTotal',
#        'HourlyNotionalCost(£)', 'IncidentNotionalCost(£)', 'FinalDescription',
#        'AnimalGroupParent', 'OriginofCall', 'PropertyType', 'PropertyCategory',
#        'SpecialServiceTypeCategory', 'SpecialServiceType', 'WardCode', 'Ward',
#        'BoroughCode', 'Borough', 'StnGroundName', 'UPRN', 'Street', 'USRN',
#        'PostcodeDistrict', 'Easting_m', 'Northing_m', 'Easting_rounded',
#        'Northing_rounded', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
pd.to_datetime(df["DateTimeOfCall"], dayfirst=True)
# Out:
# 0      2009-01-01 03:01:00
# 1      2009-01-01 08:51:00
# 2      2009-01-04 10:07:00
# 3      2009-01-05 12:27:00
# 4      2009-01-06 15:23:00
#                ...
# 8296   2022-03-28 21:11:00
# 8297   2022-03-29 19:22:00
# 8298   2022-03-30 10:48:00
# 8299   2022-03-31 04:01:00
# 8300   2022-03-31 23:51:00
# Name: DateTimeOfCall, Length: 8301, dtype: datetime64[ns]

# %%
df["DateTimeOfCall"] = pd.to_datetime(df["DateTimeOfCall"], dayfirst=True)

# %%
df["DateTimeOfCall"]
# Out:
# 0      2009-01-01 03:01:00
# 1      2009-01-01 08:51:00
# 2      2009-01-04 10:07:00
# 3      2009-01-05 12:27:00
# 4      2009-01-06 15:23:00
#                ...
# 8296   2022-03-28 21:11:00
# 8297   2022-03-29 19:22:00
# 8298   2022-03-30 10:48:00
# 8299   2022-03-31 04:01:00
# 8300   2022-03-31 23:51:00
# Name: DateTimeOfCall, Length: 8301, dtype: datetime64[ns]

# %%
df.set_index("DateTimeOfCall", inplace=True)
# Out:
#        IncidentNumber      DateTimeOfCall  CalYear  FinYear   TypeOfIncident  \
# 0              139091 2009-01-01 03:01:00     2009  2008/09  Special Service
# 1              275091 2009-01-01 08:51:00     2009  2008/09  Special Service
# 2             2075091 2009-01-04 10:07:00     2009  2008/09  Special Service
# 3             2872091 2009-01-05 12:27:00     2009  2008/09  Special Service
# 4             3553091 2009-01-06 15:23:00     2009  2008/09  Special Service
# ...               ...                 ...      ...      ...              ...
# 8296  043944-28032022 2022-03-28 21:11:00     2022  2021/22  Special Service
# 8297  044402-29032022 2022-03-29 19:22:00     2022  2021/22  Special Service
# 8298  044668-30032022 2022-03-30 10:48:00     2022  2021/22  Special Service
# 8299  045081-31032022 2022-03-31 04:01:00     2022  2021/22  Special Service
# 8300  045529-31032022 2022-03-31 23:51:00     2022  2021/22  Special Service
#
#       PumpCount  PumpHoursTotal  HourlyNotionalCost(£)  \
# 0           1.0             2.0                    255
# 1           1.0             1.0                    255
# 2           1.0             1.0                    255
# 3           1.0             1.0                    255
# 4           1.0             1.0                    255
# ...         ...             ...                    ...
# 8296        1.0             1.0                    352
# 8297        1.0             1.0                    352
# 8298        1.0             1.0                    352
# 8299        1.0             1.0                    352
# 8300        1.0             1.0                    352
#
#       IncidentNotionalCost(£)  \
# 0                       510.0
# 1                       255.0
# 2                       255.0
# 3                       255.0
# 4                       255.0
# ...                       ...
# 8296                    352.0
# 8297                    352.0
# 8298                    352.0
# 8299                    352.0
# 8300                    352.0
#
#                                        FinalDescription  ...          UPRN  \
# 0                                              Redacted  ...           NaN
# 1                                              Redacted  ...           NaN
# 2                                              Redacted  ...           NaN
# 3                                              Redacted  ...  1.000000e+11
# 4                                              Redacted  ...           NaN
# ...                                                 ...  ...           ...
# 8296  CAT TRAPPED ON ROOF     REQUESTED TO ATTEND BY...  ...           NaN
# 8297                             CAT TRAPPED UNDER LOGS  ...           NaN
# 8298               PIGEON TRAPPED IN NETTING ON BALCONY  ...           NaN
# 8299  FOX IN WATER - CALLER WILL MEET YOU ON HARBET ...  ...  1.003361e+10
# 8300                                           Redacted  ...  1.000879e+10
#
#                     Street        USRN PostcodeDistrict Easting_m Northing_m  \
# 0           Waddington Way  20500146.0             SE19       NaN        NaN
# 1            Grasmere Road         NaN             SE25  534785.0   167546.0
# 2                Mill Lane         NaN              SM5  528041.0   164923.0
# 3                Park Lane  21401484.0              UB9  504689.0   190685.0
# 4             Swindon Lane  21300122.0              RM3       NaN        NaN
# ...                    ...         ...              ...       ...        ...
# 8296       BELGRAVE STREET  22700141.0               E1       NaN        NaN
# 8297        MORRAB GARDENS  22302293.0              IG3       NaN        NaN
# 8298         GRANTHAM ROAD  22200183.0              E12       NaN        NaN
# 8299  MERCHANT SQUARE EAST   8402160.0               W2  526983.0   181593.0
# 8300            TRAM CLOSE  21903406.0             SE24  531959.0   175545.0
#
#      Easting_rounded Northing_rounded   Latitude Longitude
# 0             532350           170050        NaN       NaN
# 1             534750           167550  51.390954 -0.064167
# 2             528050           164950  51.368941 -0.161985
# 3             504650           190650  51.605283 -0.489684
# 4             554650           192350        NaN       NaN
# ...              ...              ...        ...       ...
# 8296          535950           181250        NaN       NaN
# 8297          545750           186450        NaN       NaN
# 8298          543250           185850        NaN       NaN
# 8299          526950           181550  51.518999 -0.171191
# 8300          531950           175550  51.463509 -0.101772
#
# [8301 rows x 31 columns]
